# %% [markdown]
# # 载入数据集

# %%
import cv2
import numpy as np
from tqdm import tqdm

n = 25000
width = 224

X = np.zeros((n, width, width, 3), dtype=np.uint8)
y = np.zeros((n, 2), dtype=np.uint8)

for i in tqdm(range(n/2)):
    X[i] = cv2.resize(cv2.imread('train/cat.%d.jpg' % i), (width, width))
    X[i+n/2] = cv2.resize(cv2.imread('train/dog.%d.jpg' % i), (width, width))

y[:n/2, 0] = 1
y[n/2:, 1] = 1
# Out:
# 100%|██████████| 12500/12500 [00:47<00:00, 260.62it/s]

# %% [markdown]
# # 提取特征

# %%
from keras.layers import *
from keras.models import *
from keras.applications import *
from keras.optimizers import *
from keras.regularizers import *
from keras.applications.resnet50 import preprocess_input
# Out:
# Using TensorFlow backend.

# %%
def preprocess_input(x):
    return x - [103.939, 116.779, 123.68]

# %%
def get_features(MODEL, data=X):
    cnn_model = MODEL(include_top=False, input_shape=(width, width, 3), weights='imagenet')
    
    inputs = Input((width, width, 3))
    x = inputs
    x = Lambda(preprocess_input, name='preprocessing')(x)
    x = cnn_model(x)
    x = GlobalAveragePooling2D()(x)
    cnn_model = Model(inputs, x)

    features = cnn_model.predict(data, batch_size=64, verbose=1)
    return features

# %%
features = get_features(ResNet50, X)
# Out:
# 25000/25000 [==============================] - 99s

# %% [markdown]
# # 训练模型

# %%
inputs = Input(features.shape[1:])
x = inputs
x = Dropout(0.5)(x)
x = Dense(2, activation='softmax', kernel_regularizer=l2(1e-4), bias_regularizer=l2(1e-4))(x)
model = Model(inputs, x, name='prediction')
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
h = model.fit(features, y, batch_size=128, epochs=10, validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/10
# 20000/20000 [==============================] - 0s - loss: 0.1107 - acc: 0.9557 - val_loss: 0.0598 - val_acc: 0.9782
# Epoch 2/10
# 20000/20000 [==============================] - 0s - loss: 0.0472 - acc: 0.9839 - val_loss: 0.0347 - val_acc: 0.9876
# Epoch 3/10
# 20000/20000 [==============================] - 0s - loss: 0.0388 - acc: 0.9865 - val_loss: 0.0336 - val_acc: 0.9872
# Epoch 4/10
# 20000/20000 [==============================] - 0s - loss: 0.0371 - acc: 0.9874 - val_loss: 0.0836 - val_acc: 0.9720
# Epoch 5/10
# 20000/20000 [==============================] - 0s - loss: 0.0364 - acc: 0.9873 - val_loss: 0.0585 - val_acc: 0.9792
# Epoch 6/10
# 20000/20000 [==============================] - 0s - loss: 0.0363 - acc: 0.9879 - val_loss: 0.0291 - val_acc: 0.9888
# Epoch 7/10
# 20000/20000 [==============================] - 0s - loss: 0.0340 - acc: 0.9886 - val_loss: 0.0291 - val_acc: 0.9896
# Epoch 8/10
# 20000/20000 [==============================] - 0s - loss: 0.0329 - acc: 0.9890 - val_loss: 0.0326 - val_acc: 0.9894
# Epoch 9/10
# 20000/20000 [==============================] - 0s - loss: 0.0325 - acc: 0.9890 - val_loss: 0.0614 - val_acc: 0.9794
# Epoch 10/10
# 20000/20000 [==============================] - 0s - loss: 0.0336 - acc: 0.9889 - val_loss: 0.0453 - val_acc: 0.9856

# %%
model.save('model_dense.h5')

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
weights = model.get_weights()[0]

# %%
cnn_model = ResNet50(include_top=False, input_shape=(width, width, 3), weights='imagenet')
cnn_model = Model(cnn_model.input, cnn_model.layers[-2].output, name='resnet50')

inputs = Input((width, width, 3))
x = inputs
x = cnn_model(x)
cam = Conv2D(2, 1, use_bias=False, name='cam')(x)
model_cam = Model(inputs, cam)

x = GlobalAveragePooling2D(name='gap')(x)
x = model(x)
model_clf = Model(inputs, x)

# %%
model_cam.layers[-1].set_weights([weights.reshape((1, 1, 2048, 2))])

# %%
SVG(model_to_dot(model_cam, show_shapes=True).create(prog='dot', format='svg'))

# %%
SVG(model_to_dot(model_clf, show_shapes=True).create(prog='dot', format='svg'))

# %%
import matplotlib.pyplot as plt
import random
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# 用模型进行预测
index = 13734
img = X[index]
prediction = model_clf.predict(np.expand_dims(img, 0))
prediction = prediction[0, 0]

cam = model_cam.predict(np.expand_dims(img, 0))
cam = cam[0, :, :, 1 if prediction < 0.5 else 0]

# 调整 CAM 的范围
cam /= 10
cam[cam < 0] = 0
cam[cam > 1] = 1
cam = cv2.resize(cam, (224, 224))
cam = np.uint8(255*cam)

# 染成彩色
heatmap = cv2.applyColorMap(cam, cv2.COLORMAP_JET)

# 加在原图上
out = cv2.addWeighted(img, 0.8, heatmap, 0.4, 0)

# 显示图片
plt.axis('off')
plt.imshow(out[:,:,::-1])

# %%
model_clf.save('model_clf.h5')
model_cam.save('model_cam.h5')

# %%
from coremltools.converters.keras import convert
# Out:
# WARNING:root:Keras version 2.0.8 detected. Last version known to be fully compatible of Keras is 2.0.6 .

# %%
coreml_model = convert('model_clf.h5', blue_bias=103.939, green_bias=116.779, red_bias=123.68, 
                       input_names=['image'], image_input_names='image', output_names='prediction')

coreml_model.author = 'YPW'
coreml_model.short_description = 'Dogs vs Cats'
coreml_model.license = 'MIT'
coreml_model.input_description['image'] = 'A 224x224 Image.'
coreml_model.output_description['prediction'] = 'The probability of Dog and Cat.'
coreml_model.save('model_clf.mlmodel')
# Out:
# /usr/local/lib/python2.7/dist-packages/keras/models.py:251: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# 0 : input_5, <keras.engine.topology.InputLayer object at 0x7f22701bc2d0>
# 1 : resnet50_conv1, <keras.layers.convolutional.Conv2D object at 0x7f22701bc410>
# 2 : resnet50_bn_conv1, <keras.layers.normalization.BatchNormalization object at 0x7f22701bc590>
# 3 : resnet50_activation_50, <keras.layers.core.Activation object at 0x7f22701bc850>
# 4 : resnet50_max_pooling2d_2, <keras.layers.pooling.MaxPooling2D object at 0x7f22701bca10>
# 5 : resnet50_res2a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22701bca90>
# 6 : resnet50_bn2a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22701bcad0>
# 7 : resnet50_activation_51, <keras.layers.core.Activation object at 0x7f22701bcbd0>
# 8 : resnet50_res2a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22701bcd10>
# 9 : resnet50_bn2a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22701bcd50>
# 10 : resnet50_activation_52, <keras.layers.core.Activation object at 0x7f22701bce50>
# 11 : resnet50_res2a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22701bcf90>
# 12 : resnet50_res2a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f22701bcfd0>
# 13 : resnet50_bn2a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22701cf110>
# 14 : resnet50_bn2a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f22701cf210>
# 15 : resnet50_add_17, <keras.layers.merge.Add object at 0x7f22701cf350>
# 16 : resnet50_activation_53, <keras.layers.core.Activation object at 0x7f22701cf490>
# 17 : resnet50_res2b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22701cf4d0>
# 18 : resnet50_bn2b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22701cf510>
# 19 : resnet50_activation_54, <keras.layers.core.Activation object at 0x7f22701cf610>
# 20 : resnet50_res2b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22701cf750>
# 21 : resnet50_bn2b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22701cf790>
# 22 : resnet50_activation_55, <keras.layers.core.Activation object at 0x7f22701cf890>
# 23 : resnet50_res2b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22701cf9d0>
# 24 : resnet50_bn2b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22701cfa10>
# 25 : resnet50_add_18, <keras.layers.merge.Add object at 0x7f22701cfb10>
# 26 : resnet50_activation_56, <keras.layers.core.Activation object at 0x7f22701cfc50>
# 27 : resnet50_res2c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22701cfc90>
# 28 : resnet50_bn2c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22701cfcd0>
# 29 : resnet50_activation_57, <keras.layers.core.Activation object at 0x7f22701cfdd0>
# 30 : resnet50_res2c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22701cff10>
# 31 : resnet50_bn2c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22701cff50>
# 32 : resnet50_activation_58, <keras.layers.core.Activation object at 0x7f2270157090>
# 33 : resnet50_res2c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22701571d0>
# 34 : resnet50_bn2c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270157210>
# 35 : resnet50_add_19, <keras.layers.merge.Add object at 0x7f2270157310>
# 36 : resnet50_activation_59, <keras.layers.core.Activation object at 0x7f2270157450>
# 37 : resnet50_res3a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270157490>
# 38 : resnet50_bn3a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22701574d0>
# 39 : resnet50_activation_60, <keras.layers.core.Activation object at 0x7f22701575d0>
# 40 : resnet50_res3a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270157710>
# 41 : resnet50_bn3a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270157750>
# 42 : resnet50_activation_61, <keras.layers.core.Activation object at 0x7f2270157850>
# 43 : resnet50_res3a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270157990>
# 44 : resnet50_res3a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f22701579d0>
# 45 : resnet50_bn3a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270157ad0>
# 46 : resnet50_bn3a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f2270157bd0>
# 47 : resnet50_add_20, <keras.layers.merge.Add object at 0x7f2270157d10>
# 48 : resnet50_activation_62, <keras.layers.core.Activation object at 0x7f2270157e50>
# 49 : resnet50_res3b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270157e90>
# 50 : resnet50_bn3b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270157ed0>
# 51 : resnet50_activation_63, <keras.layers.core.Activation object at 0x7f2270157fd0>
# 52 : resnet50_res3b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270160150>
# 53 : resnet50_bn3b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270160190>
# 54 : resnet50_activation_64, <keras.layers.core.Activation object at 0x7f2270160290>
# 55 : resnet50_res3b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22701603d0>
# 56 : resnet50_bn3b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270160410>
# 57 : resnet50_add_21, <keras.layers.merge.Add object at 0x7f2270160510>
# 58 : resnet50_activation_65, <keras.layers.core.Activation object at 0x7f2270160650>
# 59 : resnet50_res3c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270160690>
# 60 : resnet50_bn3c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22701606d0>
# 61 : resnet50_activation_66, <keras.layers.core.Activation object at 0x7f22701607d0>
# 62 : resnet50_res3c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270160910>
# 63 : resnet50_bn3c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270160950>
# 64 : resnet50_activation_67, <keras.layers.core.Activation object at 0x7f2270160a50>
# 65 : resnet50_res3c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270160b90>
# 66 : resnet50_bn3c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270160bd0>
# 67 : resnet50_add_22, <keras.layers.merge.Add object at 0x7f2270160cd0>
# 68 : resnet50_activation_68, <keras.layers.core.Activation object at 0x7f2270160e10>
# 69 : resnet50_res3d_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270160e50>
# 70 : resnet50_bn3d_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270160e90>
# 71 : resnet50_activation_69, <keras.layers.core.Activation object at 0x7f2270160f90>
# 72 : resnet50_res3d_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270165110>
# 73 : resnet50_bn3d_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270165150>
# 74 : resnet50_activation_70, <keras.layers.core.Activation object at 0x7f2270165250>
# 75 : resnet50_res3d_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270165390>
# 76 : resnet50_bn3d_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22701653d0>
# 77 : resnet50_add_23, <keras.layers.merge.Add object at 0x7f22701654d0>
# 78 : resnet50_activation_71, <keras.layers.core.Activation object at 0x7f2270165610>
# 79 : resnet50_res4a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270165650>
# 80 : resnet50_bn4a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270165690>
# 81 : resnet50_activation_72, <keras.layers.core.Activation object at 0x7f2270165790>
# 82 : resnet50_res4a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22701658d0>
# 83 : resnet50_bn4a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270165910>
# 84 : resnet50_activation_73, <keras.layers.core.Activation object at 0x7f2270165a10>
# 85 : resnet50_res4a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270165b50>
# 86 : resnet50_res4a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f2270165b90>
# 87 : resnet50_bn4a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270165c90>
# 88 : resnet50_bn4a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f2270165d90>
# 89 : resnet50_add_24, <keras.layers.merge.Add object at 0x7f2270165ed0>
# 90 : resnet50_activation_74, <keras.layers.core.Activation object at 0x7f227016b050>
# 91 : resnet50_res4b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f227016b090>
# 92 : resnet50_bn4b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f227016b0d0>
# 93 : resnet50_activation_75, <keras.layers.core.Activation object at 0x7f227016b1d0>
# 94 : resnet50_res4b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f227016b310>
# 95 : resnet50_bn4b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f227016b350>
# 96 : resnet50_activation_76, <keras.layers.core.Activation object at 0x7f227016b450>
# 97 : resnet50_res4b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f227016b590>
# 98 : resnet50_bn4b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f227016b5d0>
# 99 : resnet50_add_25, <keras.layers.merge.Add object at 0x7f227016b6d0>
# 100 : resnet50_activation_77, <keras.layers.core.Activation object at 0x7f227016b810>
# 101 : resnet50_res4c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f227016b850>
# 102 : resnet50_bn4c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f227016b890>
# 103 : resnet50_activation_78, <keras.layers.core.Activation object at 0x7f227016b990>
# 104 : resnet50_res4c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f227016bad0>
# 105 : resnet50_bn4c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f227016bb10>
# 106 : resnet50_activation_79, <keras.layers.core.Activation object at 0x7f227016bc10>
# 107 : resnet50_res4c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f227016bd50>
# 108 : resnet50_bn4c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f227016bd90>
# 109 : resnet50_add_26, <keras.layers.merge.Add object at 0x7f227016be90>
# 110 : resnet50_activation_80, <keras.layers.core.Activation object at 0x7f227016bfd0>
# 111 : resnet50_res4d_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270174050>
# 112 : resnet50_bn4d_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270174090>
# 113 : resnet50_activation_81, <keras.layers.core.Activation object at 0x7f2270174190>
# 114 : resnet50_res4d_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22701742d0>
# 115 : resnet50_bn4d_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270174310>
# 116 : resnet50_activation_82, <keras.layers.core.Activation object at 0x7f2270174410>
# 117 : resnet50_res4d_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270174550>
# 118 : resnet50_bn4d_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270174590>
# 119 : resnet50_add_27, <keras.layers.merge.Add object at 0x7f2270174690>
# 120 : resnet50_activation_83, <keras.layers.core.Activation object at 0x7f22701747d0>
# 121 : resnet50_res4e_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270174810>
# 122 : resnet50_bn4e_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270174850>
# 123 : resnet50_activation_84, <keras.layers.core.Activation object at 0x7f2270174950>
# 124 : resnet50_res4e_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270174a90>
# 125 : resnet50_bn4e_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270174ad0>
# 126 : resnet50_activation_85, <keras.layers.core.Activation object at 0x7f2270174bd0>
# 127 : resnet50_res4e_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270174d10>
# 128 : resnet50_bn4e_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270174d50>
# 129 : resnet50_add_28, <keras.layers.merge.Add object at 0x7f2270174e50>
# 130 : resnet50_activation_86, <keras.layers.core.Activation object at 0x7f2270174f90>
# 131 : resnet50_res4f_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270174fd0>
# 132 : resnet50_bn4f_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270188050>
# 133 : resnet50_activation_87, <keras.layers.core.Activation object at 0x7f2270188150>
# 134 : resnet50_res4f_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270188290>
# 135 : resnet50_bn4f_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22701882d0>
# 136 : resnet50_activation_88, <keras.layers.core.Activation object at 0x7f22701883d0>
# 137 : resnet50_res4f_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270188510>
# 138 : resnet50_bn4f_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270188550>
# 139 : resnet50_add_29, <keras.layers.merge.Add object at 0x7f2270188650>
# 140 : resnet50_activation_89, <keras.layers.core.Activation object at 0x7f2270188790>
# 141 : resnet50_res5a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22701887d0>
# 142 : resnet50_bn5a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270188810>
# 143 : resnet50_activation_90, <keras.layers.core.Activation object at 0x7f2270188910>
# 144 : resnet50_res5a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270188a50>
# 145 : resnet50_bn5a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270188a90>
# 146 : resnet50_activation_91, <keras.layers.core.Activation object at 0x7f2270188b90>
# 147 : resnet50_res5a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270188cd0>
# 148 : resnet50_res5a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f2270188d10>
# 149 : resnet50_bn5a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270188e10>
# 150 : resnet50_bn5a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f2270188f10>
# 151 : resnet50_add_30, <keras.layers.merge.Add object at 0x7f2270190090>
# 152 : resnet50_activation_92, <keras.layers.core.Activation object at 0x7f22701901d0>
# 153 : resnet50_res5b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2270190210>
# 154 : resnet50_bn5b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270190250>
# 155 : resnet50_activation_93, <keras.layers.core.Activation object at 0x7f2270190350>
# 156 : resnet50_res5b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270190490>
# 157 : resnet50_bn5b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22701904d0>
# 158 : resnet50_activation_94, <keras.layers.core.Activation object at 0x7f22701905d0>
# 159 : resnet50_res5b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270190710>
# 160 : resnet50_bn5b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270190750>
# 161 : resnet50_add_31, <keras.layers.merge.Add object at 0x7f2270190850>
# 162 : resnet50_activation_95, <keras.layers.core.Activation object at 0x7f2270190990>
# 163 : resnet50_res5c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22701909d0>
# 164 : resnet50_bn5c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2270190a10>
# 165 : resnet50_activation_96, <keras.layers.core.Activation object at 0x7f2270190b10>
# 166 : resnet50_res5c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2270190c50>
# 167 : resnet50_bn5c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2270190c90>
# 168 : resnet50_activation_97, <keras.layers.core.Activation object at 0x7f2270190d90>
# 169 : resnet50_res5c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2270190ed0>
# 170 : resnet50_bn5c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2270190f10>
# 171 : resnet50_add_32, <keras.layers.merge.Add object at 0x7f2270117050>
# 172 : resnet50_activation_98, <keras.layers.core.Activation object at 0x7f2270117190>
# 173 : gap, <keras.layers.pooling.GlobalAveragePooling2D object at 0x7f2269d9be10>
# 174 : prediction_dense_1, <keras.layers.core.Dense object at 0x7f2269d174d0>
# 175 : prediction_dense_1__activation__, <keras.layers.core.Activation object at 0x7f227027a450>

# %%
coreml_model = convert('model_cam.h5', blue_bias=103.939, green_bias=116.779, red_bias=123.68, 
                       input_names=['image'], image_input_names='image', output_names='cam')

coreml_model.author = 'YPW'
coreml_model.short_description = 'Dogs vs Cats'
coreml_model.license = 'MIT'
coreml_model.input_description['image'] = 'A 224x224 Image.'
coreml_model.output_description['cam'] = 'The cam Image.'
coreml_model.save('model_cam.mlmodel')
# Out:
# 0 : input_5, <keras.engine.topology.InputLayer object at 0x7f2268070390>
# 1 : resnet50_conv1, <keras.layers.convolutional.Conv2D object at 0x7f22680704d0>
# 2 : resnet50_bn_conv1, <keras.layers.normalization.BatchNormalization object at 0x7f2268070650>
# 3 : resnet50_activation_50, <keras.layers.core.Activation object at 0x7f2268070910>
# 4 : resnet50_max_pooling2d_2, <keras.layers.pooling.MaxPooling2D object at 0x7f2268070b50>
# 5 : resnet50_res2a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2268070bd0>
# 6 : resnet50_bn2a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268070c10>
# 7 : resnet50_activation_51, <keras.layers.core.Activation object at 0x7f2268070d10>
# 8 : resnet50_res2a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268070e50>
# 9 : resnet50_bn2a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2268070e90>
# 10 : resnet50_activation_52, <keras.layers.core.Activation object at 0x7f2268070f90>
# 11 : resnet50_res2a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268480110>
# 12 : resnet50_res2a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f2268480150>
# 13 : resnet50_bn2a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268480250>
# 14 : resnet50_bn2a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f2268480350>
# 15 : resnet50_add_17, <keras.layers.merge.Add object at 0x7f2268480490>
# 16 : resnet50_activation_53, <keras.layers.core.Activation object at 0x7f22684805d0>
# 17 : resnet50_res2b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2268480610>
# 18 : resnet50_bn2b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268480650>
# 19 : resnet50_activation_54, <keras.layers.core.Activation object at 0x7f2268480750>
# 20 : resnet50_res2b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268480890>
# 21 : resnet50_bn2b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684808d0>
# 22 : resnet50_activation_55, <keras.layers.core.Activation object at 0x7f22684809d0>
# 23 : resnet50_res2b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268480b10>
# 24 : resnet50_bn2b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268480b50>
# 25 : resnet50_add_18, <keras.layers.merge.Add object at 0x7f2268480c50>
# 26 : resnet50_activation_56, <keras.layers.core.Activation object at 0x7f2268480d90>
# 27 : resnet50_res2c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2268480dd0>
# 28 : resnet50_bn2c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268480e10>
# 29 : resnet50_activation_57, <keras.layers.core.Activation object at 0x7f2268480f10>
# 30 : resnet50_res2c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268483090>
# 31 : resnet50_bn2c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684830d0>
# 32 : resnet50_activation_58, <keras.layers.core.Activation object at 0x7f22684831d0>
# 33 : resnet50_res2c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268483310>
# 34 : resnet50_bn2c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268483350>
# 35 : resnet50_add_19, <keras.layers.merge.Add object at 0x7f2268483450>
# 36 : resnet50_activation_59, <keras.layers.core.Activation object at 0x7f2268483590>
# 37 : resnet50_res3a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684835d0>
# 38 : resnet50_bn3a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268483610>
# 39 : resnet50_activation_60, <keras.layers.core.Activation object at 0x7f2268483710>
# 40 : resnet50_res3a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268483850>
# 41 : resnet50_bn3a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2268483890>
# 42 : resnet50_activation_61, <keras.layers.core.Activation object at 0x7f2268483990>
# 43 : resnet50_res3a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268483ad0>
# 44 : resnet50_res3a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f2268483b10>
# 45 : resnet50_bn3a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268483c10>
# 46 : resnet50_bn3a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f2268483d10>
# 47 : resnet50_add_20, <keras.layers.merge.Add object at 0x7f2268483e50>
# 48 : resnet50_activation_62, <keras.layers.core.Activation object at 0x7f2268483f90>
# 49 : resnet50_res3b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2268483fd0>
# 50 : resnet50_bn3b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268494050>
# 51 : resnet50_activation_63, <keras.layers.core.Activation object at 0x7f2268494150>
# 52 : resnet50_res3b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268494290>
# 53 : resnet50_bn3b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684942d0>
# 54 : resnet50_activation_64, <keras.layers.core.Activation object at 0x7f22684943d0>
# 55 : resnet50_res3b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268494510>
# 56 : resnet50_bn3b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268494550>
# 57 : resnet50_add_21, <keras.layers.merge.Add object at 0x7f2268494650>
# 58 : resnet50_activation_65, <keras.layers.core.Activation object at 0x7f2268494790>
# 59 : resnet50_res3c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684947d0>
# 60 : resnet50_bn3c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268494810>
# 61 : resnet50_activation_66, <keras.layers.core.Activation object at 0x7f2268494910>
# 62 : resnet50_res3c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f2268494a50>
# 63 : resnet50_bn3c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f2268494a90>
# 64 : resnet50_activation_67, <keras.layers.core.Activation object at 0x7f2268494b90>
# 65 : resnet50_res3c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f2268494cd0>
# 66 : resnet50_bn3c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f2268494d10>
# 67 : resnet50_add_22, <keras.layers.merge.Add object at 0x7f2268494e10>
# 68 : resnet50_activation_68, <keras.layers.core.Activation object at 0x7f2268494f50>
# 69 : resnet50_res3d_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f2268494f90>
# 70 : resnet50_bn3d_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f2268494fd0>
# 71 : resnet50_activation_69, <keras.layers.core.Activation object at 0x7f226849d110>
# 72 : resnet50_res3d_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f226849d250>
# 73 : resnet50_bn3d_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f226849d290>
# 74 : resnet50_activation_70, <keras.layers.core.Activation object at 0x7f226849d390>
# 75 : resnet50_res3d_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f226849d4d0>
# 76 : resnet50_bn3d_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f226849d510>
# 77 : resnet50_add_23, <keras.layers.merge.Add object at 0x7f226849d610>
# 78 : resnet50_activation_71, <keras.layers.core.Activation object at 0x7f226849d750>
# 79 : resnet50_res4a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f226849d790>
# 80 : resnet50_bn4a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f226849d7d0>
# 81 : resnet50_activation_72, <keras.layers.core.Activation object at 0x7f226849d8d0>
# 82 : resnet50_res4a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f226849da10>
# 83 : resnet50_bn4a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f226849da50>
# 84 : resnet50_activation_73, <keras.layers.core.Activation object at 0x7f226849db50>
# 85 : resnet50_res4a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f226849dc90>
# 86 : resnet50_res4a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f226849dcd0>
# 87 : resnet50_bn4a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f226849ddd0>
# 88 : resnet50_bn4a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f226849ded0>
# 89 : resnet50_add_24, <keras.layers.merge.Add object at 0x7f22684a5050>
# 90 : resnet50_activation_74, <keras.layers.core.Activation object at 0x7f22684a5190>
# 91 : resnet50_res4b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684a51d0>
# 92 : resnet50_bn4b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684a5210>
# 93 : resnet50_activation_75, <keras.layers.core.Activation object at 0x7f22684a5310>
# 94 : resnet50_res4b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684a5450>
# 95 : resnet50_bn4b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684a5490>
# 96 : resnet50_activation_76, <keras.layers.core.Activation object at 0x7f22684a5590>
# 97 : resnet50_res4b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684a56d0>
# 98 : resnet50_bn4b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684a5710>
# 99 : resnet50_add_25, <keras.layers.merge.Add object at 0x7f22684a5810>
# 100 : resnet50_activation_77, <keras.layers.core.Activation object at 0x7f22684a5950>
# 101 : resnet50_res4c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684a5990>
# 102 : resnet50_bn4c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684a59d0>
# 103 : resnet50_activation_78, <keras.layers.core.Activation object at 0x7f22684a5ad0>
# 104 : resnet50_res4c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684a5c10>
# 105 : resnet50_bn4c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684a5c50>
# 106 : resnet50_activation_79, <keras.layers.core.Activation object at 0x7f22684a5d50>
# 107 : resnet50_res4c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684a5e90>
# 108 : resnet50_bn4c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684a5ed0>
# 109 : resnet50_add_26, <keras.layers.merge.Add object at 0x7f22684a5fd0>
# 110 : resnet50_activation_80, <keras.layers.core.Activation object at 0x7f22684af150>
# 111 : resnet50_res4d_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684af190>
# 112 : resnet50_bn4d_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684af1d0>
# 113 : resnet50_activation_81, <keras.layers.core.Activation object at 0x7f22684af2d0>
# 114 : resnet50_res4d_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684af410>
# 115 : resnet50_bn4d_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684af450>
# 116 : resnet50_activation_82, <keras.layers.core.Activation object at 0x7f22684af550>
# 117 : resnet50_res4d_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684af690>
# 118 : resnet50_bn4d_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684af6d0>
# 119 : resnet50_add_27, <keras.layers.merge.Add object at 0x7f22684af7d0>
# 120 : resnet50_activation_83, <keras.layers.core.Activation object at 0x7f22684af910>
# 121 : resnet50_res4e_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684af950>
# 122 : resnet50_bn4e_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684af990>
# 123 : resnet50_activation_84, <keras.layers.core.Activation object at 0x7f22684afa90>
# 124 : resnet50_res4e_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684afbd0>
# 125 : resnet50_bn4e_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684afc10>
# 126 : resnet50_activation_85, <keras.layers.core.Activation object at 0x7f22684afd10>
# 127 : resnet50_res4e_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684afe50>
# 128 : resnet50_bn4e_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684afe90>
# 129 : resnet50_add_28, <keras.layers.merge.Add object at 0x7f22684aff90>
# 130 : resnet50_activation_86, <keras.layers.core.Activation object at 0x7f22684b6110>
# 131 : resnet50_res4f_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684b6150>
# 132 : resnet50_bn4f_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6190>
# 133 : resnet50_activation_87, <keras.layers.core.Activation object at 0x7f22684b6290>
# 134 : resnet50_res4f_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684b63d0>
# 135 : resnet50_bn4f_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6410>
# 136 : resnet50_activation_88, <keras.layers.core.Activation object at 0x7f22684b6510>
# 137 : resnet50_res4f_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684b6650>
# 138 : resnet50_bn4f_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6690>
# 139 : resnet50_add_29, <keras.layers.merge.Add object at 0x7f22684b6790>
# 140 : resnet50_activation_89, <keras.layers.core.Activation object at 0x7f22684b68d0>
# 141 : resnet50_res5a_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684b6910>
# 142 : resnet50_bn5a_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6950>
# 143 : resnet50_activation_90, <keras.layers.core.Activation object at 0x7f22684b6a50>
# 144 : resnet50_res5a_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684b6b90>
# 145 : resnet50_bn5a_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6bd0>
# 146 : resnet50_activation_91, <keras.layers.core.Activation object at 0x7f22684b6cd0>
# 147 : resnet50_res5a_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684b6e10>
# 148 : resnet50_res5a_branch1, <keras.layers.convolutional.Conv2D object at 0x7f22684b6e50>
# 149 : resnet50_bn5a_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684b6f50>
# 150 : resnet50_bn5a_branch1, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7090>
# 151 : resnet50_add_30, <keras.layers.merge.Add object at 0x7f22684c71d0>
# 152 : resnet50_activation_92, <keras.layers.core.Activation object at 0x7f22684c7310>
# 153 : resnet50_res5b_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684c7350>
# 154 : resnet50_bn5b_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7390>
# 155 : resnet50_activation_93, <keras.layers.core.Activation object at 0x7f22684c7490>
# 156 : resnet50_res5b_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684c75d0>
# 157 : resnet50_bn5b_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7610>
# 158 : resnet50_activation_94, <keras.layers.core.Activation object at 0x7f22684c7710>
# 159 : resnet50_res5b_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684c7850>
# 160 : resnet50_bn5b_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7890>
# 161 : resnet50_add_31, <keras.layers.merge.Add object at 0x7f22684c7990>
# 162 : resnet50_activation_95, <keras.layers.core.Activation object at 0x7f22684c7ad0>
# 163 : resnet50_res5c_branch2a, <keras.layers.convolutional.Conv2D object at 0x7f22684c7b10>
# 164 : resnet50_bn5c_branch2a, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7b50>
# 165 : resnet50_activation_96, <keras.layers.core.Activation object at 0x7f22684c7c50>
# 166 : resnet50_res5c_branch2b, <keras.layers.convolutional.Conv2D object at 0x7f22684c7d90>
# 167 : resnet50_bn5c_branch2b, <keras.layers.normalization.BatchNormalization object at 0x7f22684c7dd0>
# 168 : resnet50_activation_97, <keras.layers.core.Activation object at 0x7f22684c7ed0>
# 169 : resnet50_res5c_branch2c, <keras.layers.convolutional.Conv2D object at 0x7f22684d1050>
# 170 : resnet50_bn5c_branch2c, <keras.layers.normalization.BatchNormalization object at 0x7f22684d1090>
# 171 : resnet50_add_32, <keras.layers.merge.Add object at 0x7f22684d1190>
# 172 : resnet50_activation_98, <keras.layers.core.Activation object at 0x7f22684d12d0>
# 173 : cam, <keras.layers.convolutional.Conv2D object at 0x7f22618bac90>
